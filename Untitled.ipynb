# %%
import pandas as pd
df = pd.read_csv("volcanoes.csv")

# %%
df
# Out:
#                         Region    Number         Volcano Name   Country  \
# 0                  West Indies  1600-21-               Piparo  Trinidad
# 1                  West Indies  1600-08=   Diables, Morne aux  Dominica
# 2                  West Indies  1600-09=    Diablotins, Morne  Dominica
# 3                  West Indies  1600-11=     Plat Pays, Morne  Dominica
# 4                  West Indies  1600-10=  Trois Pitons, Morne  Dominica
# ...                        ...       ...                  ...       ...
# 1566   Melanesia and Australia  0507-08-  NE Shepherd Islands   Vanuatu
# 1567   Melanesia and Australia  0507-081           North Vate   Vanuatu
# 1568   Melanesia and Australia  0507-01=          Suretamatai   Vanuatu
# 1569   Melanesia and Australia  0507-09=       Traitor's Head   Vanuatu
# 1570   Melanesia and Australia  0507-10=                Yasur   Vanuatu
#
#                 Location  Latitude  Longitude  Elevation (m)             Type  \
# ...

# %%
df.describe()
# Out:
#           Latitude    Longitude  Elevation (m)
# count  1571.000000  1571.000000    1566.000000
# mean     14.686419    23.415143    1624.821839
# std      31.940257   112.861177    1630.288854
# min     -78.500000  -179.970000   -6000.000000
# 25%      -6.725000   -78.162000     655.250000
# 50%      14.070000    38.120000    1448.500000
# 75%      42.390000   137.570500    2334.750000
# max      88.270000   179.580000    6879.000000

# %%
df.Type.value_counts()
# Out:
# Type
# Stratovolcano          704
# Shield volcano         169
# Submarine volcano      142
# Volcanic field          95
# Caldera                 84
# Cinder cone             76
# Complex volcano         53
# Lava dome               37
# Pyroclastic cone        36
# Maar                    19
# Fissure vent            19
# Unknown                 17
# Tuff cone               13
# Compound volcano        11
# Stratovolcanoes          9
# Crater rows              8
# Pyroclastic cones        8
# Scoria cone              7
# Pyroclastic shield       6
# Somma volcano            5
# Subglacial volcano       5
# Submarine volcanoes      5
# Cinder cones             4
# Submarine volcano?       4
# Explosion crater         4
# Fumarole field           4
# Lava cone                4
# Lava domes               3
# Scoria cones             3
# Pumice cone              3
# Cone                     3
# Volcanic complex         2
# Hydrothermal field       2
# Shield volcanoes         2
# ...
